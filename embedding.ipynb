# %% [markdown]
# ### 기본 세팅

# %%
# !pip install torch
# !pip install pandas
# !pip install mxnet
# !pip install tqdm
# !pip install kss
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/74/07/edce54779f5c3fe8ab8390eafad3d7c8190fce68f922a254ea77f4a94a99/torch-2.1.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    -------------------------------------- 192.3/192.3 MB 902.7 kB/s eta 0:00:00
# ...
#   WARNING: The scripts convert-caffe2-to-onnx.exe, convert-onnx-to-caffe2.exe and torchrun.exe are installed in 'C:\Users\user\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 33.1/33.1 MB 1.3 MB/s eta 0:00:00
# ...

# %%
# !pip install mxnet
# !pip install mxnet
# !pip install gluonnlp==0.8.0
# !pip install tqdm pandas
# !pip install sentencepiece
# !pip install transformers
# !pip install torch>=1.8.1
# !pip install gluonnlp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached mxnet-1.7.0.post2-py2.py3-none-win_amd64.whl (33.1 MB)
# ...
#   Using cached numpy-1.16.6.zip (5.1 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached requests-2.18.4-py2.py3-none-any.whl (88 kB)
# ...
#   Using cached graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# ...
#   Using cached idna-2.6-py2.py3-none-any.whl (56 kB)
# ...
#   Using cached urllib3-1.22-py2.py3-none-any.whl (132 kB)
# ...
#   Running setup.py clean for numpy
# Failed to build numpy
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [1895 lines of output]
#   Running from numpy source directory.
# ...

# %%
import os
import torch
# import numpy as np
# import pandas as pd
# import re
# import ast
# from tqdm.notebook import tqdm
# from kss import split_sentences
# # import gluonnlp as nlp
# from sentence_transformers import SentenceTransformer, util
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %% [markdown]
# ### 데이터 로드

# %%
import pandas as pd
df_original    = pd.read_csv('사건원문.csv')
df_kor_ratio5  = pd.read_csv('한글태그_5%적용.csv')
df_kor_ratio10 = pd.read_csv('한글태그_10%적용.csv')
df_eng_ratio5  = pd.read_csv('영어태그_5%적용.csv')
df_eng_ratio10 = pd.read_csv('영어태그_10%적용.csv')
#df_TEST = pd.read_csv('TEST.csv',encoding='cp949')
# df_TEST2 = pd.read_csv('영태50.csv',encoding='cp949')
# df_TEST3 = pd.read_csv('FINAL.csv',encoding='cp949')
# datanames = ['original', 'kor_ratio5', 'kor_ratio10', 'eng_ratio5', 'eng_ratio10']
#datanames = ['original']
# datanames = ['TEST3']
#datanames = ['kor_ratio5']
# datanames = ['kor_ratio10']
# datanames = ['eng_ratio5']
# datanames = ['eng_ratio10']

# %%
datanames = ['original', 'kor_ratio5', 'kor_ratio10', 'eng_ratio5', 'eng_ratio10']

# %%
import ast

# 문자열의 리스트화
def str2list(textdata, attribute):
    textdata = [ast.literal_eval(case) for case in textdata[attribute]]
    return textdata
# 데이터프레임 내용 리스트화

for dataname in datanames:
    rawdataframe = globals()[f'df_{dataname}']
    globals()[f'{dataname}_content'] = str2list(rawdataframe, '내용')

# %% [markdown]
# ### ngram 세팅

# %%
# 입력 content를 ngram 리스트로 변환
def content2ngram(content, n):
    """
        content: 사건 내용 리스트 
        n: ngram으로 자를 단위
    """
    ngram_list = []     # 전체 텍스트 ngram
    for case in content:
        cut_count = len(case)-n     # ngram으로 자를 횟수
        ngram_case = []             # 사건당 ngram
        
        for i in range(cut_count):
            ngram_group = ''     # 합쳐질 ngram
            for j in range(n):
                if j != 0: ngram_group += ' '
                ngram_group += case[i+j]     # 문장 합쳐서 붙임
            ngram_case.append(ngram_group)
        ngram_list.append(ngram_case)
    return ngram_list

# %%
# 데이터 ngram 변환
for dataname in datanames:
    rawdata = globals()[f'{dataname}_content']
    for n in [2, 3, 4]:     # 2gram, 3gram, 4gram 데이터 생성
        globals()[f'{dataname}_content_{n}gram_embedding'] = content2ngram(rawdata, n)

# %% [markdown]
# ### sentence transformer 임베딩

# %%
import numpy as np

# %%
# 데이터 ngram별 임베딩 저장
for dataname in datanames:
    for n in [2, 3, 4]:
        cur_ngram_embedding = globals()[f'{dataname}_content_{n}gram_embedding']
        np.save(f'C:/Users/user/Downloads/voice/save_embeddings/{dataname}_{n}gram_embedding.npy', np.array(cur_ngram_embedding, dtype=object))
        print(f' {dataname} {n}gram embedding saved')
        
# CSV로 저장
        csv_filename = f'C:/Users/user/Downloads/voice/save_embeddings/{dataname}_{n}gram_embedding.csv'
        np.savetxt(csv_filename, cur_ngram_embedding, delimiter=',', fmt='%s')
        
        print(f'{dataname} {n}gram embedding saved as both npy and csv')
# Out:
#  original 2gram embedding saved
# original 2gram embedding saved as both npy and csv
#  original 3gram embedding saved
# original 3gram embedding saved as both npy and csv
#  original 4gram embedding saved
# original 4gram embedding saved as both npy and csv
#  kor_ratio5 2gram embedding saved
# kor_ratio5 2gram embedding saved as both npy and csv
#  kor_ratio5 3gram embedding saved
# C:\Users\user\.conda\envs\voice\lib\site-packages\numpy\lib\npyio.py:1378: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.asarray(X)
# kor_ratio5 3gram embedding saved as both npy and csv
#  kor_ratio5 4gram embedding saved
# kor_ratio5 4gram embedding saved as both npy and csv
#  kor_ratio10 2gram embedding saved
# kor_ratio10 2gram embedding saved as both npy and csv
# ...
